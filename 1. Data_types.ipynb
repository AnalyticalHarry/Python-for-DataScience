# %% [markdown]
# # Data Types

# %% [markdown]
# ### <font color="red">Hemant Thapa

# %% [markdown]
# ### Input and output – how logic work, in simple language and how value is store in variable

# %% [markdown]
# ### Python variable

# %% [markdown]
#  a = 1 , a is varibale and 1 is value stored

# %% [markdown]
# if we print variable, we will get output as a value

# %%
a = 1 
print(a)
# Out:
# 1

# %% [markdown]
# We can also directly print value

# %%
print(1)
# Out:
# 1

# %% [markdown]
# ### DATA TYPES

# %% [markdown]
# ![large.png](attachment:large.png)

# %% [markdown]
# ### 1. String

# %% [markdown]
# Strings – String data and some basic string operations.

# %% [markdown]
# Most programming languages have a data type called a string, which is used for data values that are made up of ordered sequences of characters, such as "hello world". A string can contain any sequence of characters, visible or invisible, and characters may be repeated. The number of characters in the string is called its length, and "hello world" has length 11 - made up of 10 letters and 1 space. There is usually a restriction on the maximum length of a string. There is also such a thing as an empty string, which contains no characters - length 0.

# %% [markdown]
# ![Ways-to-declare-a-string-In-Python-1024x576.png](attachment:Ways-to-declare-a-string-In-Python-1024x576.png)

# %% [markdown]
# Example 1

# %%
#String
name = "hello world"
print(name)
# Out:
# hello world

# %%
type(name)
# Out:
# str

# %% [markdown]
# Example 2

# %%
my_pet = "Simmy" 
print(my_pet)
# Out:
# Simmy

# %%
type(my_pet)
# Out:
# str

# %% [markdown]
# Example 3

# %%
value = "123"
print(value)
# Out:
# 123

# %%
type(value)
# Out:
# str

# %% [markdown]
# Example 4

# %%
var = "'Harry Worlds'"
print(var)
# Out:
# 'Harry Worlds'

# %% [markdown]
# #### String Concatenation

# %%
a = "Hello"
b = " "
c = "World"
print(a+b+c)
# Out:
# Hello World

# %%
name = "Julia"
string = name + " like to read book"
print(string)
# Out:
# Julia like to read book

# %% [markdown]
# ####  String .format

# %%
word = "like to read book"
string =  "Julia {}".format(word)
print(string)
# Out:
# Julia like to read book

# %% [markdown]
# #### f-string

# %%
name = "Shaina"
state = f"{name} like to listen music"
print(state)
# Out:
# Shaina like to listen music

# %% [markdown]
# #### old style

# %%
name = "harry".title()
string = "Hello, %s" %name
print(string)
# Out:
# Hello, Harry

# %% [markdown]
# ### 2. String Indexing

# %% [markdown]
# A character (also called element) of a string can be accessed with it's index number. In Python, index number starts with 0 in forwa5rd direction and -1 in backward direction. The figure below describes the indexing concept of a string.5

# %% [markdown]
# ![python-string.png](attachment:python-string.png)

# %% [markdown]
# Forward direction indexing

# %%
str = "Python"
print(str)
# Out:
# Python

# %%
str[0]
# Out:
# 'P'

# %%
str[1]
# Out:
# 'y'

# %%
str[2]
# Out:
# 't'

# %%
str[3]
# Out:
# 'h'

# %%
str[4]
# Out:
# 'o'

# %%
str[5]
# Out:
# 'n'

# %%
#Python String Concatenation through forward indexing
str[0]+str[1]+str[2]+str[3]+str[4]+str[5]
# Out:
# 'Python'

# %% [markdown]
# Backward direction indexing

# %%
str[-6]
# Out:
# 'P'

# %%
str[-5]
# Out:
# 'y'

# %%
str[-4]
# Out:
# 't'

# %%
str[-3]
# Out:
# 'h'

# %%
str[-2]
# Out:
# 'o'

# %%
str[-1]
# Out:
# 'n'

# %%
#Python String Concatenation through forward indexing
str[-6]+str[-5]+str[-4]+str[-3]+str[-2]+str[-1]
# Out:
# 'Python'

# %%
value = "123"
print(value)
# Out:
# 123

# %%
value[0] + value[1] + value[2]
# Out:
# '123'

# %% [markdown]
# Space in string

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
"Hello world"[5] #space is in 5th index
# Out:
# ' '

# %%
name = "J o h n"

# %%
name[0]
# Out:
# 'J'

# %%
name[1] #1st space place in string
# Out:
# ' '

# %%
name[2]
# Out:
# 'o'

# %%
name[3] #second space place in string
# Out:
# ' '

# %%
name[4]
# Out:
# 'h'

# %%
name[5] #Third space place in string
# Out:
# ' '

# %%
name[6]
# Out:
# 'n'

# %% [markdown]
# ### 3. Integer (whole number)

# %% [markdown]
# Integers include positive numbers, negative numbers, and zero. 'Integer' is a Latin word which means 'whole' or 'intact'. This means integers do not include fractions or decimals.

# %% [markdown]
# ![integer.png](attachment:integer.png)

# %% [markdown]
# In Python, integers are zero, positive or negative whole numbers without a fractional part and having unlimited precision, e.g. 0, 100, -10. The followings are valid integer literals in Python.

# %%
value = 2
print(value)
# Out:
# 2

# %%
type(value)
# Out:
# int

# %%
a = 123
b = 456
c = 789
print(a+b+c)
# Out:
# 1368

# %%
#validation
123+456+789
# Out:
# 1368

# %% [markdown]
# ### 4. Floating point (decimal number)

# %% [markdown]
# ![Place_value.png](attachment:Place_value.png)

# %% [markdown]
# The float type in Python represents the floating point number. Float is used to represent real numbers and is written with a decimal point dividing the integer and fractional parts. For example, 97.98, 32.3+e18, -32.54e100 all are floating point numbers.
#
# Python float values are represented as 64-bit double-precision values. The maximum value any floating-point number can be is approx 1.8 x 10308. Any number greater than this will be indicated by the string inf in Python.

# %%
a = 15
b = 7.5
c = b/c
print(c)
# Out:
# 0.009505703422053232

# %%
type(c)
# Out:
# float

# %%
x = 12.5
y = 15.0
print("y is a data type: ",type(y))
print("x is a data type: ",type(x))
# Out:
# y is a data type:  <class 'float'>
# x is a data type:  <class 'float'>

# %% [markdown]
# Conversion of int to float

# %%
a = 12 
b = (float(a))
print("str data before conversion: " , a)
print("float data after conversion: ", b)
type(b)
# Out:
# str data before conversion:  12
# float data after conversion:  12.0
# float

# %% [markdown]
# ### 5. Boolean

# %% [markdown]
# The Python Boolean type is one of Python’s built-in data types. It’s used to represent the truth value of an expression. For example, the expression 1 <= 2 is True, while the expression 0 == 1 is False. Understanding how Python Boolean values behave is important to programming well in Python.

# %% [markdown]
# The Python Boolean type has only two possible values:
#
# 1. True
# 2. False

# %%
1<=2
# Out:
# True

# %%
0==1
# Out:
# False

# %%
a = 1
b = 2
a==b
# Out:
# False

# %%
type(a==b)
# Out:
# bool

# %% [markdown]
# #### Always capitalize the first letter of True and False

# %%
type(True) 
type(False)
# Out:
# bool

# %%
x = True
y = False
print(x,y)
type(x)
# Out:
# True False
# bool

# %% [markdown]
# ### 6. Cast boolean

# %% [markdown]
# You can cast a value to a boolean using the function bool(). If you cast a variable, the data type is changed. In the example below it goes from data type int to boolean.

# %%
value = 1
boolean = bool(value)
print(boolean)
# Out:
# True

# %%
value = 0
boolean = bool(value)
print(boolean)
# Out:
# False

# %%
type(value)
# Out:
# int

# %%
type(boolean)
# Out:
# bool

# %% [markdown]
# ### 7. Boolean strings

# %%
variable = "Hello World"
variable.isalnum()
# Out:
# False

# %%
variable = "123"
variable.isalnum()
# Out:
# True

# %%
variable = "HelloWorld"
variable.isalpha()
# Out:
# True

# %%
variable = "Hello World" #Space can make statement False
variable.isalpha()
# Out:
# False

# %%
variable = "123"
variable.isdigit()
# Out:
# True

# %%
variable = "Hello World" #Tilte contain space
variable.istitle()
# Out:
# True

# %%
variable = "HelloWorld"
variable.istitle()
# Out:
# False

# %%
variable = "HELLO WORLD"
variable.isupper()
# Out:
# True

# %%
variable = "harry world"
variable.islower()
# Out:
# True

# %%
variable = "harry world"
variable.islower()
# Out:
# True

# %%
variable = "  "
variable.isspace()
# Out:
# True

# %%
variable = "Hello World"
variable.endswith("d")
# Out:
# True

# %%
variable = "Hello World"
variable.startswith("H")
# Out:
# True

# %%
variable = "Hello World".lower()
variable.startswith("h", print(variable))
# Out:
# hello world
# True

# %% [markdown]
# #### 8. Input and Output - How logic works

# %%
a = int(input("Input: ")) 
#int is Built-in function, which specify input must be in integer 
#The input() function allows user input.
print("Output:", a)
# Out:
# Input: 12345
# Output: 12345

# %%
user = (input("What is your name?: "))
#default function is string
#The input() function allows user input.
print("Output: ", user)
# Out:
# What is your name?: John
# Output:  John

# %%
user = input("What is your name?: ")
length = len(user)
print("length of your name: ", length)
# Out:
# What is your name?: Shannon
# length of your name:  7
